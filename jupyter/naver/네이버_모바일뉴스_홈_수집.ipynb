# %%
# 오픈 라이브러리
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from pymongo import MongoClient
client = MongoClient()
import inspect
import pprint
pp = pprint.PrettyPrinter(indent=2)

# 나의 라이브러리
import sys
sys.path.append('/Users/sambong/p/lib/')
import __pymongo as mg
import __string as sh
import __list as lh

# 프로젝트 라이브러리
from NEWS_PJT import *
db = client[DB명]
from collect_naver_m_news import (
    모바일_뉴스_수집,
)

# 전역변수
NAVER_mNEWS_URI = 'http://m.news.naver.com'
네이버_모바일_뉴스홈_url = NAVER_mNEWS_URI + '/home.nhn'

# %%
# 쥬피터 노트북 전용


import pandas as pd
from bson.objectid import ObjectId
from pandas.io.json import json_normalize
import json


import debugger as dbg


from collect_naver_m_newsHome import (
    네이버_모바일뉴스_uri,
)
from collect_naver import(
    뉴스수집시_공통정보_추가후_저장,
)

# %%
tbl명  = '화면배치'
'''
db[tbl명].insert_one({
    '거래성향':거래성향,
})

#mg.테이블의_백업csv_생성(db명, tbl명, data_path+'__바로이전자료__')

db[tbl명].update_many(
    {},
#    {'_id':ObjectId('5b2fda6cb94e316470c1e043')},
    {'$unset':{'화면계층순위':''}},
)
'''
#__현재 작업 자료 백업 
#mg.테이블의_중복제거(db명, tbl명)#, subset=['언론인명','언론사명']
mg.테이블의_백업csv_생성(db명, tbl명, data_path)

# %%
# Out:
# { '각_뉴스_수집': { '1 화면배치 href 개수': 1103,
#                '2 뉴스_url 개수': 886,
#                '3 #1 - #2 개수': 217,
#                '4 LSD 포함된 href 개수': 41}}
#
# ==================================================각_뉴스_수집, 1/41, href:http://m.news.naver.com/read.nhn?oid=001&aid=0010103204&sid1=100&mode=LSD
#
# { '__누가_파싱': { '뉴스_url': 'http://m.news.naver.com/read.nhn?oid=001&aid=0010103204&sid1=100&mode=LSD',
#                '수집일시': datetime.datetime(2018, 7, 2, 21, 1, 9, 975665),
#                '언론사명': '연합뉴스',
#                '언론인명': '차대운 기자 '}}
# { '언론인_파싱후_저장': { '기자의_뉴스모음페이지_url': 'http://media.naver.com/j/56632?oid=001',
#                   '언론사명': '연합뉴스',
#                   '언론인명': '차대운 기자 ',
#                   '이메일': None}}
# { '언론사_파싱후_저장': { '언론사_url': 'http://www.yonhapnews.co.kr',
#                   '언론사_로고_url': 'https://mimgnews.pstatic.net/image/upload/office_logo/001/2017/01/11/logo_001_6_20170111151211.jpg',
#                   '언론사명': '연합뉴스'}}
# ...
