# %%
from thenews.__lib__ import *
#import Layout as lay
from Layout_Analyzer import *
import __pymongo as mg
LAYOUT_SUBSET = ['페이지명','영역명','수집일시','뉴스제목','href']
위치COL_LI = ['페이지명','영역명','영역배치순위','뉴스배치순위','첫화면_배치여부']
# Out:
# # # # # # /Users/sambong/p/news/NEWS_PJT.py # # # # #
#
# # # # # # /Users/sambong/p/lib/LIB_PJT.py # # # # #
#
# # # # # # /Users/sambong/p/lib/__debug.py # # # # #
#
# # # # # # /Users/sambong/p/lib/__pymongo.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/pymongoLib.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/Loader.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/Inserter.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/SaveDeduplicator.py # # # # #
#
# # # # # # /Users/sambong/p/lib/__list.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/Backup.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/Updater.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/Report.py # # # # #
#
# # # # # # /Users/sambong/p/lib/PyMongo/DB_Handler.py # # # # #
#
# # # # # # /Users/sambong/p/news/Layout_Analyzer.py # # # # #
#
# # # # # # /Users/sambong/p/news/Layout_.py # # # # #

# %% [markdown]
# # 화면배치TBL 과 화면배치_v2 TBL 간의 동기화

# %%
df1 = mg.find(db명=DB명, tbl명='화면배치', query=None, projection=None, dbg_on=False, 컬럼순서li=[], df보고형태='df')
# Out:
# ============================================================find
# {'tbl명': '화면배치'}
#
# ============================================================funclog
# { 'log_dic': { 'caller': 'find',
#                'db명': '뉴스',
#                'df보고형태': 'df',
#                'projection': None,
#                'query': 'None',
#                'tbl명': '화면배치',
#                '실행시간_overSec': 10,
#                '실행시간_sec': 3.082708,
#                '측정일시': datetime.datetime(2018, 9, 10, 15, 20, 2, 210920),
#                '컬럼순서li': []}}

# %%
len(df1)
# Out:
# 136096

# %%
grouped = df1.groupby(위치COL_LI)
len(grouped)
# Out:
# 2601

# %%
df2 = mg.find(db명=DB명, tbl명='화면배치_v2', query=None, projection=None, dbg_on=False, 컬럼순서li=[], df보고형태='df')
# Out:
# ============================================================find
# {'tbl명': '화면배치_v2'}

# %%
len(df2)
# Out:
# 10948

# %%
href_li = list(df2['href'])

# %%
query = {'href':{'$in':href_li}}
#projection = {'_id':1}
df11 = mg.find(db명=DB명, tbl명='화면배치', query=query, projection=None, dbg_on=False, 컬럼순서li=[], df보고형태='df')
# Out:
# ============================================================find
# {'tbl명': '화면배치'}

# %%
len(df11)
# Out:
# 24084

# %%
from Layout_ import 위치COL_LI
grouped = df11.groupby(위치COL_LI)
len(grouped)
# Out:
# 10

# %%
query = {'href':{'$nin':href_li}}
#projection = {'_id':1}
df12 = mg.find(db명=DB명, tbl명='화면배치', query=query, projection=None, dbg_on=False, 컬럼순서li=[], df보고형태='df')
# Out:
# ============================================================find
# {'tbl명': '화면배치'}
#
# ============================================================funclog
# { 'log_dic': { 'caller': 'find',
#                'db명': '뉴스',
#                'df보고형태': 'df',
#                'projection': None,
#                'query': "{'href': {'$nin': "
#                         "['https://m.search.naver.com/search.naver?query=%EA%B8%B0%EC%83%81%ED%8A%B9%EB%B3%B4&where=m&sm=mtp_lfw&acr=1', "
#                         "'https://m.news.naver.com/read.nhn?mode=LSD&sid1=103&sid2=245&oid=056&aid=0010614544', "
#                         "'https://m.news.naver.com/read.nhn?mode=LSD&sid1=101&sid2=263&oid=055&aid=0000670352', "
#                         "'https://m.news.naver.com/hotissue/main.nhn?sid1=100&cid=1079165&gid=1079155&dummy=1808282234', "
#                         "'https://m.news.naver.com/read.nhn?mode=LSD&sid1=102&sid2=257&oid=052&aid=0001186841', "
# ...

# %%
len(df12)
# Out:
# 112012

# %%
grouped = df12.groupby(위치COL_LI)
len(grouped)
# Out:
# 2601

# %%
df13 = df1.fillna('_None')

# %%
grouped = df13.groupby(위치COL_LI)
len(grouped)
# Out:
# 58

# %%
df13.groupby(위치COL_LI).count()
# Out:
#                                                _id  class  data-area  \
# 페이지명        영역명       영역배치순위 뉴스배치순위 첫화면_배치여부
# 네이버_모바일뉴스_홈 _None     _None  1.0    _None      265    265        265
#                              2.0    _None      259    259        259
#                              3.0    _None      255    255        255
#                              4.0    _None      261    261        261
#                              5.0    _None      255    255        255
#                              6.0    _None      254    254        254
#                              _None  _None     1001   1001       1001
#             많이본뉴스     4.0    1.0    N            4      4          4
#                                     _None     4427   4427       4427
#                              2.0    N            4      4          4
#                                     _None     4427   4427       4427
#                              3.0    N            4      4          4
# ...

# %%
df13[ df13['영역명']=='_None' ]
# Out:
#                            _id  class data-area data-clk data-gdid data-rank  \
# 14    5b050c4bb94e314293f3fc33  _None     _None    _None     _None     _None
# 19    5b050c4cb94e314293f3fc3c  _None     _None    _None     _None     _None
# 22    5b050c4db94e314293f3fc47  _None     _None    _None     _None     _None
# 23    5b050c4db94e314293f3fc4c  _None     _None    _None     _None     _None
# 25    5b050c4eb94e314293f3fc56  _None     _None    _None     _None     _None
# 26    5b050c4eb94e314293f3fc60  _None     _None    _None     _None     _None
# 27    5b050c4fb94e314293f3fc65  _None     _None    _None     _None     _None
# 28    5b050c4fb94e314293f3fc6a  _None     _None    _None     _None     _None
# 29    5b050c50b94e314293f3fc6f  _None     _None    _None     _None     _None
# 30    5b050c51b94e314293f3fc74  _None     _None    _None     _None     _None
# 31    5b050c51b94e314293f3fc79  _None     _None    _None     _None     _None
# ...
