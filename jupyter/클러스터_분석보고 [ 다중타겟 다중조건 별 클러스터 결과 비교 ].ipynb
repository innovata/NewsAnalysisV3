# %%
from thenews.__lib__ import *
from NEWSPJT import *
import __matplotlib as mpl
import __pymongo as mg
import pandas as pd
# Out:
# # # # # # /Users/sambong/p/news/NEWSPJT.py # # # # #
#
# # # # # # /Users/sambong/p/news/Event.py # # # # #
#
# # # # # # /Users/sambong/p/lib/__matplotlib.py # # # # #
#
# # # # # # /Users/sambong/p/lib/matplotlib/Pie.py # # # # #
#
# # # # # # /Users/sambong/p/lib/matplotlib/Histo.py # # # # #

# %% [markdown]
# # 2차원 그래프
#
# - X축 : bin = label 개수
# - Y축 : 사건 개수 = keyid 개수
# - 변수 : sampling, n_cluster, clst_col, algorithm
# - 고정변수은 무엇인가 : 독립변수 한개를 제외한 3개
# - 독립변수는 무엇인가 : 한개, 알고리즘별, 클러스터 타겟별,
# - 종속변수는 무엇인가 : label, keyid

# %%
ML.cluster.클러스터알고리즘별_표준편차_비교_scatterplot_3D()

# %%
df.groupby(['sampling', 'n_clusters', 'clst_col']).count()
# Out:
#                                            keyid  label  algorithm  clst_tbl  \
# sampling n_clusters clst_col
# 1000     50         뉴스본문                    1936   1936       1936      1936
#                     뉴스본문srl_WSDNNGli        1936   1936       1936      1936
#                     뉴스본문srl_WSDNNGli_중복제거   1936   1936       1936      1936
#                     뉴스제목                    1936   1936       1936      1936
#                     뉴스제목srl_WSDNNGli        1678   1678       1678      1678
#          67         뉴스본문                    1922   1922       1922      1922
#                     뉴스본문srl_WSDNNGli        1922   1922       1922      1922
#                     뉴스본문srl_WSDNNGli_중복제거   1922   1922       1922      1922
#                     뉴스제목                    1922   1922       1922      1922
#                     뉴스제목srl_WSDNNGli        1700   1700       1700      1700
#          100        뉴스본문                    1934   1934       1934      1934
# ...
